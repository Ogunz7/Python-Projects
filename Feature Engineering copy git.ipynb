# %% [markdown]
# ## Feature Engineering
#  A feature is a measurable characteristic or property that provides information for a machine learning model.
#
# Let's assume our goal in this analysis is to understand how Zillow's ZESTIMATE price  is determined. What value, for example do the number of bedrooms, bathrooms, etc. play?  But that isn't really feature engineering! **You have those columns already.**  If you were competing on Kaggle, limiting your features to the data that you have wouldn't move you to the head of the pack.
#
# Feature engineering takes time, energy, and insight. It can require detective work and research beyond what is in the data.  It can involve combinining or leveraging the columnar data in unique and imaginative ways.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('OldNewark.csv')
df
# Out:
#       ID  STREETNO    STREET  ZESTIMATE  SQFT  BEDR  BATHR  YRBUILT  LOTSIZE  \
# 0    150       504     Apple     244069  1960     3    2.0     1400     0.36
# 1    151       602     Apple     259061  1963     3    2.0     1950     0.29
# 2     23       120  Townsend     303508  1800     3    3.0     1903     0.35
# 3     95        56    Sunset     307445  2186     4    3.0     1915     0.26
# 4     99        45    Sunset     297546  1625     3    1.5     1915     0.27
# ..   ...       ...       ...        ...   ...   ...    ...      ...      ...
# 161   98        52    Sunset     303987  2050     3    3.0     1985     0.26
# 162   97        54    Sunset     296163  1800     3    1.0     1986     0.26
# 163  115        17   Indian      342428  2350     3    2.5     1987     0.33
# 164   74       124   Winslow     349367  2225     4    2.5     1989     0.49
# 165   45       271   Beverly     499119  5025     5    4.5     2004     0.26
#
#       SOLDFOR  YRSOLD
# 0         NaN     NaN
# 1    250000.0  2006.0
# 2    183000.0  1997.0
# 3    532000.0  2007.0
# 4         NaN     NaN
# ..        ...     ...
# 161       NaN     NaN
# 162       NaN     NaN
# 163   40100.0  1986.0
# 164   38500.0  1987.0
# 165   81100.0  2004.0
#
# [166 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['ID', 'STREETNO', 'STREET', 'ZESTIMATE', 'SQFT', 'BEDR', 'BATHR',
#        'YRBUILT', 'LOTSIZE', 'SOLDFOR', 'YRSOLD'],
#       dtype='object')

# %% [markdown]
# Some explanations:
# * ZESTIMATE: This is the Zillow.com estimate of the house's value
# * SQFT: Square footage of the house
# * LOTSIZE: size of the lot, in acres
# * SOLDFOR: This is the amount that the house last sold for.
# * YRSOLD: This is the date that the house was last purchased

# %%
df.isnull().sum()
# Out:
# ID            0
# STREETNO      0
# STREET        0
# ZESTIMATE     0
# SQFT          0
# BEDR          0
# BATHR         0
# YRBUILT       0
# LOTSIZE       0
# SOLDFOR      44
# YRSOLD       44
# dtype: int64

# %%
df['STREET'].value_counts()
# Out:
# Apple       44
# Beverly     33
# Sunset      23
# Winslow     22
# Orchard     19
# Townsend    11
# Indian       8
# Grantham     6
# Name: STREET, dtype: int64

# %% [markdown]
# ### Swim in your data
#
# Take a few minutes to explore the OldNewark dataset.  Print out the first five rows or so.  Run descriptive statistics, do some histogram plots, and run some value counts.  You might run some example scatterplots.  Scatterplots that approximate a line are good candidates for regression.  Scatterplots that look like a blob do not!
#
# __MOST IMPORTANTLY: TAKE YOUR TIME AT THIS STAGE.  Good data scientists spend only about 10% of their time running stats models.  Most of the time is understanding the data and doing feature engineering (which we will do in a minute).  REMEMBER: The stats models are easy.  Understanding the data is harder (but critical)!__
#
# ### Reflection
# Write out at least five **interesting** things you have learned about the data.  You could comment on:
# * Ranges of different columns (low and high values)
# * Distributions (e.g., using histograms, etc.)
# * Identification of possible outliers
# * Trends (from scatterplots)
# * Descriptive stats
# * Missing data.  Why do certain columns have so many missing values and other do not?  Is this a problem?
# * Value counts
# * Correlations
# * Anything else you notice

# %%
df['ZESTIMATE'].groupby(df['STREET']).mean()
# Out:
# STREET
# Apple       267425.363636
# Beverly     283566.060606
# Grantham    292952.500000
# Indian      321595.875000
# Orchard     392737.052632
# Sunset      295282.304348
# Townsend    352095.727273
# Winslow     338099.227273
# Name: ZESTIMATE, dtype: float64

# %%
df.describe().transpose()
# Out:
#            count           mean            std        min          25%  \
# ID         166.0      83.500000      48.064193       1.00      42.2500
# STREETNO   166.0     248.204819     163.428996      15.00     121.7500
# ZESTIMATE  166.0  307347.054217   66620.775343  196710.00  268143.2500
# SQFT       166.0    2174.728916     682.799979    1050.00    1750.0000
# BEDR       166.0       3.512048       0.744580       1.00       3.0000
# BATHR      166.0       2.328313       0.848731       1.00       2.0000
# YRBUILT    166.0    1951.319277      45.388697    1400.00    1949.0000
# LOTSIZE    166.0       0.335301       0.087044       0.17       0.2725
# SOLDFOR    122.0  260441.180328  128707.344343   12000.00  172850.0000
# YRSOLD     122.0    2004.950820      12.306588    1971.00    1999.2500
#
#                   50%        75%        max
# ID             83.500     124.75     166.00
# STREETNO      230.000     378.00     611.00
# ZESTIMATE  298821.000  340988.00  613238.00
# SQFT         2125.000    2518.75    5427.00
# BEDR            3.000       4.00       6.00
# BATHR           2.000       2.50       6.50
# YRBUILT      1957.000    1961.00    2004.00
# LOTSIZE         0.315       0.37       0.68
# SOLDFOR    258125.000  340000.00  600000.00
# YRSOLD       2006.500    2016.00    2019.00

# %% [markdown]
# * Average ZESTIMATE is \\$305K, but avg SOLDFOR is \\$260K.  Average YRSOLD is 2005.
# * Average size house is 2138 SQFT with 3.5 BEDR and 2.5 BATHS
# * On avg houses were built in 1947, but std dev is fairly high (54 yrs)

# %%
plt.title('Zillow Estimate vs. Frequency')
plt.xlabel('Zillow Estimate')
plt.ylabel('Frequency')
plt.hist(df['ZESTIMATE'])
plt.show()

# %%
plt.title('SQFT vs. Frequency')
plt.xlabel('SQFT')
plt.ylabel('Frequency')
plt.hist(df['SQFT'])
plt.show()

# %%
plt.title('YRBUILT vs. Frequency')
plt.xlabel('YRBUILT')
plt.ylabel('Frequency')
plt.hist(df['YRBUILT'])
plt.show()

# %% [markdown]
# **From descriptive statistics we noticed that 1400 in YRBUILT is an outlier and probably a mistake in the data entry. In the following, I check the house for which we have YRBUILT=1400. It seems like the value under SQFT is actually the YRBUILT and the value under YRBUILT is actually the SQFT. Therefore, we are going to fix this mistake.**

# %%
df.loc[df['YRBUILT'] == 1400]
# Out:
#     ID  STREETNO STREET  ZESTIMATE  SQFT  BEDR  BATHR  YRBUILT  LOTSIZE  \
# 0  150       504  Apple     244069  1960     3    2.0     1400     0.36
#
#    SOLDFOR  YRSOLD
# 0      NaN     NaN

# %%
df.loc[df['YRBUILT'] == 1400, 'YRBUILT'] = 1960
df.loc[df['SQFT'] == 1960, 'SQFT'] = 1400

# %%
df.corr()
# Out:
#                  ID  STREETNO  ZESTIMATE      SQFT      BEDR     BATHR  \
# ID         1.000000  0.340771  -0.444298 -0.214015 -0.003133 -0.279344
# STREETNO   0.340771  1.000000  -0.422981 -0.245099 -0.034934 -0.262255
# ZESTIMATE -0.444298 -0.422981   1.000000  0.734791  0.363996  0.706982
# SQFT      -0.214015 -0.245099   0.734791  1.000000  0.405574  0.657077
# BEDR      -0.003133 -0.034934   0.363996  0.405574  1.000000  0.494798
# BATHR     -0.279344 -0.262255   0.706982  0.657077  0.494798  1.000000
# YRBUILT    0.433442  0.209009  -0.192363  0.068036  0.009682 -0.078297
# LOTSIZE   -0.246499 -0.156489   0.340007  0.276527  0.136471  0.251942
# SOLDFOR   -0.377508 -0.130535   0.497601  0.280854  0.175498  0.286011
# YRSOLD    -0.084401  0.102945   0.047970 -0.069698 -0.042371 -0.056447
#
#             YRBUILT   LOTSIZE   SOLDFOR    YRSOLD
# ID         0.433442 -0.246499 -0.377508 -0.084401
# STREETNO   0.209009 -0.156489 -0.130535  0.102945
# ZESTIMATE -0.192363  0.340007  0.497601  0.047970
# SQFT       0.068036  0.276527  0.280854 -0.069698
# BEDR       0.009682  0.136471  0.175498 -0.042371
# BATHR     -0.078297  0.251942  0.286011 -0.056447
# YRBUILT    1.000000 -0.046505 -0.399611 -0.154098
# LOTSIZE   -0.046505  1.000000  0.132217  0.003346
# SOLDFOR   -0.399611  0.132217  1.000000  0.635992
# YRSOLD    -0.154098  0.003346  0.635992  1.000000

# %% [markdown]
# **Scatterplot**

# %%
plt.title('Zillow Estimate vs. Square Footage')
plt.xlabel('Square Footage')
plt.ylabel('Zillow Estimate')
plt.scatter(df['SQFT'], df['ZESTIMATE'])

# %%
plt.title('SOLDFOR vs. Square Footage')
plt.xlabel('Square Footage')
plt.ylabel('SOLDFOR')
plt.scatter(df['SQFT'], df['SOLDFOR'])

# %%
df.groupby('STREET').mean()
# Out:
#              ID    STREETNO      ZESTIMATE         SQFT      BEDR     BATHR  \
# STREET
# Apple     138.5  417.022727  267425.363636  1951.227273  3.522727  2.000000
# Beverly    47.0  324.181818  283566.060606  2040.151515  3.333333  2.181818
# Grantham  163.5  204.833333  292952.500000  2291.666667  3.666667  2.333333
# Indian    112.5  112.375000  321595.875000  2225.000000  3.125000  2.687500
# Orchard    10.0  246.631579  392737.052632  2583.000000  3.736842  2.894737
# Sunset     97.0   99.173913  295282.304348  1930.913043  3.478261  2.086957
# Townsend   25.0   64.545455  352095.727273  2275.454545  3.454545  2.954545
# Winslow    74.5  106.818182  338099.227273  2599.909091  3.727273  2.522727
#
#               YRBUILT   LOTSIZE        SOLDFOR       YRSOLD
# STREET
# Apple     1961.181818  0.304318  207314.551724  2005.310345
# Beverly   1957.090909  0.344848  215579.629630  2004.000000
# Grantham  1963.666667  0.323333  216600.000000  2003.000000
# Indian    1956.500000  0.365000  203233.333333  1998.500000
# Orchard   1935.631579  0.358421  471076.923077  2010.846154
# Sunset    1953.521739  0.274348  276870.588235  2005.470588
# Townsend  1942.000000  0.351818  302875.000000  2007.250000
# Winslow   1959.045455  0.410909  257932.470588  2002.588235

# %% [markdown]
# ### Feature engineering: your turn

# %% [markdown]
# I want you to do some feature engineering.
#
# **IMPORTANT: Visit Zillow.com and look over the information for the houses.  Look at the satellite map.  Think creatively.  I want you to propose three new features that will provide possible insight into understanding the ZESTIMATE value.**
#
# * List three new features that you might derive from existing data.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# #### Implementing Feature Engineering: Manipulating Your DataFrame
# To create features, you will need to manipulate the data in your dataframe.  Fortunately, Pandas dataframes are very flexible, and are also very intuitive to manipulate.
# ### Feature 1: East side versus West side facing houses
# Houses that face east get the sun in the morning on the front of the house; therefore, they also get the sun on the backyard in the evening. This often makes back patios unusable on east-facing houses.  For that reason, there is some evidence that west-facing houses will be more desirable.

# %%
# Create a new FACEWEST column.  
# The value should be 1 if the house faces west; 0 otherwise
df2 = df.copy() # keep original dataframe intact.  make deep copy

df2['FACEWEST'] = 0
df2.loc[df2['STREETNO'] % 2 == 1, 'FACEWEST'] = 1

# %% [markdown]
# ### Feature 2: Orchard versus Everything Else
# Assume we perceive that houses are worth more in Orchard than other streets, and want to explore whether or not that is true.
#
# Create a new ORCHARD column in your dataframe that has the value of 1 if the house is on Orchard and 0 otherwise.

# %%
# Create the ORCHARD column:

df2['ORCHARD'] = 0
df2.loc[df2['STREET'] == 'Orchard', 'ORCHARD'] = 1

# %% [markdown]
# ### Feature 3: Age
# The year a house was built will likely be a misleading variable, since it starts with 1920 and goes to 1972.  Instead, let's include the age of the house, which we can easily calculate from today's year.
#
# Create a new column called AGE.

# %%
# Create the AGE column

df2['AGE'] = 2021 - df2['YRBUILT']

# %% [markdown]
# ### Feature 4: Coverage
# Everyone wants a house with a nice lawn.  To determine the size of the lawn, let's look at the size of the house, relative to the size of the lot.  Houses that are large will likely command a higher price.  But a big house that has no yard may be less desirable.
#
# Create a COVERAGE variable that represents the percentage of space that the house covers on the lot.  Make whatever assumptions you feel are reasonable.

# %%
lotsqft = df2['LOTSIZE'] * 43560   # converting acres to square feet
house_size = df2['SQFT']/2         # assume two stories
df2['COVERAGE'] = (house_size / lotsqft) * 100

# %% [markdown]
# ### Feature 5: SALESAGE

# %%
df2['SALESAGE'] = df2['YRSOLD'] - df2['YRBUILT']

# %% [markdown]
# ## Examine some Visualizations
# Regression is based on the assumnption of a linear relationship between two or more features.  The first step is to examine some plots to see how variables relate to each other.

# %%
import seaborn as sns
sns.scatterplot(x="SQFT", y="ZESTIMATE", data=df2)
# Out:
# <AxesSubplot:xlabel='SQFT', ylabel='ZESTIMATE'>

# %%
sns.pairplot(df2[['ZESTIMATE', 'SQFT', 'BEDR', 'BATHR',
       'YRBUILT', 'LOTSIZE', 'SOLDFOR', 'YRSOLD']], height=1.5)

# %% [markdown]
# Remember that our dependent variables (that is, the ones that we are mostly interested in explaining or predicting) will be ZESTIMATE or SOLDFOR.  Which variables have the most obvious linear relationships?

# %%
corr = df2.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_eaaec516_4243_11ec_98cf_106530eade1crow0_col0,#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col1,#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col2,#T_eaaec516_4243_11ec_98cf_106530eade1crow3_col3,#T_eaaec516_4243_11ec_98cf_106530eade1crow4_col4,#T_eaaec516_4243_11ec_98cf_106530eade1crow5_col5,#T_eaaec516_4243_11ec_98cf_106530eade1crow6_col6,#T_eaaec516_4243_11ec_98cf_106530eade1crow7_col7,#T_eaaec516_4243_11ec_98cf_106530eade1crow8_col8,#T_eaaec516_4243_11ec_98cf_106530eade1crow9_col9,#T_eaaec516_4243_11ec_98cf_106530eade1crow10_col10,#T_eaaec516_4243_11ec_98cf_106530eade1crow11_col11,#T_eaaec516_4243_11ec_98cf_106530eade1crow12_col12,#T_eaaec516_4243_11ec_98cf_106530eade1crow13_col13,#T_eaaec516_4243_11ec_98cf_106530eade1crow14_col14{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col1,#T_eaaec516_4243_11ec_98cf_106530eade1crow13_col5{
#             background-color:  #62a2cb;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col2,#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col5,#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col11,#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col3,#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col10,#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col1,#T_eaaec516_4243_11ec_98cf_106530eade1crow6_col8,#T_eaaec516_4243_11ec_98cf_106530eade1crow6_col9,#T_eaaec516_4243_11ec_98cf_106530eade1crow6_col12,#T_eaaec516_4243_11ec_98cf_106530eade1crow6_col14,#T_eaaec516_4243_11ec_98cf_106530eade1crow7_col13,#T_eaaec516_4243_11ec_98cf_106530eade1crow9_col4,#T_eaaec516_4243_11ec_98cf_106530eade1crow11_col0,#T_eaaec516_4243_11ec_98cf_106530eade1crow12_col6,#T_eaaec516_4243_11ec_98cf_106530eade1crow13_col7{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col3{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col4{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col6{
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col7{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col8,#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col2,#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col5{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col9{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col10{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col12{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col13,#T_eaaec516_4243_11ec_98cf_106530eade1crow6_col7,#T_eaaec516_4243_11ec_98cf_106530eade1crow11_col9,#T_eaaec516_4243_11ec_98cf_106530eade1crow12_col5{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow0_col14{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col0,#T_eaaec516_4243_11ec_98cf_106530eade1crow9_col12{
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col4{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col6,#T_eaaec516_4243_11ec_98cf_106530eade1crow4_col5{
#             background-color:  #4094c3;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col7{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col8{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col9,#T_eaaec516_4243_11ec_98cf_106530eade1crow10_col5,#T_eaaec516_4243_11ec_98cf_106530eade1crow14_col13{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col11,#T_eaaec516_4243_11ec_98cf_106530eade1crow4_col0{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col12,#T_eaaec516_4243_11ec_98cf_106530eade1crow11_col13{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col13,#T_eaaec516_4243_11ec_98cf_106530eade1crow8_col4,#T_eaaec516_4243_11ec_98cf_106530eade1crow10_col3{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow1_col14,#T_eaaec516_4243_11ec_98cf_106530eade1crow10_col0{
#             background-color:  #9fbad9;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col0{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col3{
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col4,#T_eaaec516_4243_11ec_98cf_106530eade1crow13_col8{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col5{
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col6,#T_eaaec516_4243_11ec_98cf_106530eade1crow4_col7{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col7,#T_eaaec516_4243_11ec_98cf_106530eade1crow7_col2{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col8{
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col9,#T_eaaec516_4243_11ec_98cf_106530eade1crow5_col0,#T_eaaec516_4243_11ec_98cf_106530eade1crow6_col2,#T_eaaec516_4243_11ec_98cf_106530eade1crow9_col5{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col10,#T_eaaec516_4243_11ec_98cf_106530eade1crow11_col4,#T_eaaec516_4243_11ec_98cf_106530eade1crow12_col1,#T_eaaec516_4243_11ec_98cf_106530eade1crow14_col0{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col11{
#             background-color:  #2a88bc;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col12{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col13,#T_eaaec516_4243_11ec_98cf_106530eade1crow13_col2{
#             background-color:  #3b92c1;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow2_col14{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow3_col0{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow3_col1{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow3_col2,#T_eaaec516_4243_11ec_98cf_106530eade1crow8_col14{
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow3_col4{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_eaaec516_4243_11ec_98cf_106530eade1crow3_col5{
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }#T_eaaec516_4243_11ec_98cf_10653
